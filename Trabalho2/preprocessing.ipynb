# %%
import preprocessing as pre

# %%
final_text = pre.preProcessText("sourcetexts/text01.txt",
              "sourcetexts/pt_stopwords.txt")

# %%
final_text.sort()

# %%
final_text.count("católica")
# Out:
# 1

# %%
final_text
# Out:
# ['',
#  '(em',
#  '1517',
#  '1517,',
#  '1521.',
#  '1]',
#  '31',
#  '95',
#  'abusivas',
#  'acadêmica',
#  'acerca',
#  'acordo',
#  'acreditando',
#  'afirmado',
#  'afirmavam',
#  'afirmou',
#  'afixado',
#  'alberto',
#  'alemanha',
#  'alemanha,',
#  'anexadas',
#  'anualmente',
#  'apesar',
#  'arbítrio.',
#  'arcebispo',
#  'argumentou',
#  'arrependimento',
#  'atos',
#  'boas',
#  'bula',
#  'carta',
#  'castelo',
#  'católica',
#  'católica.',
#  'certificados',
#  'cisma',
#  'comemorada',
#  'cometidos',
#  'compradores',
#  'comprando',
#  'confissão',
#  'considerada',
#  'considerava',
#  'contribuindo',
#  'costume',
#  'crenças',
#  'cristo',
#  'cristãos',
#  'culminou',
#  'daquelas',
#  'dar',
#  'data',
#  'debate',
#  'declaratione',
#  'desafiaram',
#  'descoberta',
#  'desencorajam',
#  'dia',
#  'difusão',
#  'discorrem',
#  'discutidas',
#  'disputa',
#  'disputatio',
#  'disputação',
#  'distribuídas',
#  'divergiram',
#  'dividiriam',
#  'doutor',
# ...
